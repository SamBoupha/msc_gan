# %%
import pandas as pd

# %%
# !ls
# Out:
#  calf_muscle.ipynb     generator_model	      output
#  discriminator_model  'loss analysis.ipynb'   output1

# %%
columns = ['epoch','time','d1_loss','d2_loss','g_loss']

# %%
log = pd.read_csv('output/1593634291.8595984_0.0003/logs/log.csv', names=columns)

# %%
log.head()
# Out:
#    epoch      time  d1_loss  d2_loss  g_loss
# 0      1   17.499s    0.139    1.858   3.361
# 1      2   15.857s    2.812    0.803   1.387
# 2      3   15.886s    0.310    0.082   3.007
# 3      4   15.939s    0.525    0.152   2.575
# 4      5   15.934s    0.039    0.115   5.612

# %%
log[['d1_loss', 'd2_loss']].plot()

# %%
log[['g_loss']].plot()

# %%
d7e05 = pd.read_csv('logD7e05.csv', names=columns)

# %%
d7e05[['d1_loss', 'd2_loss']].plot()

# %%
d7e05[['g_loss']].plot()
